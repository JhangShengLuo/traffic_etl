# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import bokeh
# %matplotlib inline
import sys
default_stdout = sys.stdout
default_stderr = sys.stderr
reload(sys)
sys.stdout = default_stdout
sys.stderr = default_stderr
sys.setdefaultencoding('utf-8')

# %%
# !ls
# Out:
# 0314road_dict.txt                     cj20170504.csv
# 0428_pre.csv                          cluster_six.csv
# VD0405.xlsx                           etl_db_pandas.ipynb
# VD0426.xlsx                           etl_pre_all_value_v170501.ipynb
# ZC.csv                                monthly_jamp_congest_try_simple.ipynb
# accu                                  read_display_data.ipynb
# all_in_one_0106_v3.ipynb              road_split.ipynb
# area_vd                               small_test.xlsx
# cj20170426.csv                        speed
# cj20170501.csv                        taipei_road.ipynb

# %%
thisweekpre = pd.read_csv("cj20170504.csv")

# %%
xls='VD0426.xlsx'
vd_info_excel_df=pd.read_excel(xls,encoding='utf-8');
# 先去讀 excel

# %%
# %store -r modelneed

# %%
# vd_info_excel_df

# %%
len(vd_info_excel_df)
# Out:
# 848

# %%
modelneed.vd=modelneed.vd.str.decode("utf-8")
modelneed.direct=modelneed.direct.str.decode("utf-8")
notcomplet=pd.merge(vd_info_excel_df,modelneed,on=["vd","direct"])

# %%
# stackoverflow 試試

merged = df.merge(other, how='left', indicator=True)
merged

# %%
sortby_cluster_list=pd.read_csv("cluster_six.csv",encoding="utf-8")

# %%
sortby_cluster_list.rename(index=str,columns= {'Unnamed: 0':'jkjk'});sortby_cluster_list
# Out:
#      Unnamed: 0       vd  sortby  cut direct
# 0             0  V0UVS20       0    0     往東
# 1             1  V1CRT60       1    1     往東
# 2             2  V1IUI20       2    0     往東
# 3             3  V1NMM20       3    2     往東
# 4             4  V2110C0       4    1      東
# 5             5  V2120C0       5    1      東
# 6             6  V2130C0       6    0      東
# 7             7  V2RTQ20       7    3     往東
# 8             8  V2WUA20       8    0     往東
# 9             9  V3110C0       9    1      東
# 10           10  V42E2E0      10    0      東
# 11           11  V5AAF60      11    3     往東
# 12           12  V5B2R20      12    4     往東
# 13           13  V9FKW40      13    0     往東
# 14           14  V9FLB00      14    4     往東
# 15           15  V9HKV40      15    0     往東
# 16           16  VACTV20      16    5     往東
# 17           17  VAWVC20      17    0     往東
# 18           18  VDYN960      18    0     往東
# 19           19  VE4A420      19    2     往東
# 20           20  VEFM0C0      20    0      東
# 21           21  VEZPT20      21    3     往東
# 22           22  VF9KB20      22    0     往東
# 23           23  VF9KW60      23    1     往東
# 24           24  VFPMQ20      24    0     往東
# 25           25  VFTLH60      25    2     往東
# 26           26  VFZK620      26    4     往東
# 27           27  VG6J520      27    0     往東
# 28           28  VG8IK60      28    5     往東
# 29           29  VGBBW20      29    0     往東
# ..          ...      ...     ...  ...    ...
# 813         813  VP6JY60     813    2     往西
# 814         814  VP8GI60     814    2      西
# 815         815  VQDLJ20     815    0     往西
# 816         816  VQEJF20     816    2     往西
# 817         817  VQEUU60     817    0     往西
# 818         818  VQFHC20     818    0     往西
# 819         819  VQFHV60     819    1     往西
# 820         820  VQGGJ20     820    2     往西
# 821         821  VQKWL60     821    1     往西
# 822         822  VQKWL61     822    5     向西
# 823         823  VSDPM60     823    4     往西
# 824         824  VSEMV60     824    2     往西
# 825         825  VSGLN60     825    1     往西
# 826         826  VSGRX60     826    2     往西
# 827         827  VSHZU60     827    0     往西
# 828         828  VSJJX20     828    2     往西
# 829         829  VSM4D60     829    2      西
# 830         830  VSM4D61     830    0      西
# 831         831  VSPRA60     831    2     往西
# 832         832  VSQYA00     832    5     往西
# 833         833  VTEZS61     833    0      西
# 834         834  VU8EF20     834    3     往西
# 835         835  VW7HN20     835    0     往西
# 836         836  VWGIV60     836    0     往西
# 837         837  VWRLS20     837    3     往西
# 838         838  VX9KL60     838    0     往西
# 839         839  VXSLB20     839    0     往西
# 840         840  VXWNW20     840    0     往西
# 841         841  VZAJE60     841    2     往西
# 842         842  VZLKH60     842    2     往西
#
# [843 rows x 5 columns]

# %%
vd_info_excel_dfc=vd_info_excel_df.copy()
vd_info_excel_dfc.insert(2,"redirect",vd_info_excel_dfc.direct)


pattern= {'redirect':{u'.?東$':'東',u'.?西$':'西',u'.?南$':'南',u'.?北$':'北',u'.向放置':'未指定'}}
# 把方向改成統一規格

vd_info_excel_dfc=vd_info_excel_dfc.replace(pattern,regex=True);

# %%
vd_info_excel_dfc=vd_info_excel_dfc.rename(index=str,columns={"direct":"olddirect","redirect":"direct"})

# %%
sortby_cluster_list.vd=sortby_cluster_list.vd.str.decode("utf-8")
sortby_cluster_list.direct=sortby_cluster_list.direct.str.decode("utf-8")

realdf=pd.merge(sortby_cluster_list,vd_info_excel_dfc.ix[:,[0,1,2]],on=["vd","direct"])

# %%
realdf=realdf.drop("direct",axis=1)
realdf=realdf.rename(index=str,columns={"olddirect":"direct"})

# %%
realdf.to_csv("cluster_six.csv",index=False,encoding="utf-8")

# %%
float(len(modelneed))/168
# Out:
# 854.0

# %%
float(len(notcomplet))/168
# Out:
# 830.0
