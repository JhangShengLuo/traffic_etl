# %%
import numpy as np
import pandas as pd
import jieba as jb
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import time
import datetime
import os
import re
import io
import csv
import shutil
import sys
import mysql.connector as sql
from mysql.connector import MySQLConnection, Error
default_stdout = sys.stdout
default_stderr = sys.stderr
reload(sys)
sys.stdout = default_stdout
sys.stderr = default_stderr
sys.setdefaultencoding('utf-8')

# %%
vdname_table=pd.read_csv('XEVD.csv').ix[:,0].tolist()

# %%
import time
tStart = time.time()

db_connection = sql.connect(host='localhost', database='for1121', user='root', password='apple')
frames = []
for ele in vdname_table:
    frames.append(pd.read_sql('SELECT * FROM {r}'.format(r=ele), con=db_connection))

result = pd.concat(frames, ignore_index=True)

tEnd = time.time()
print "It cost %f sec" % (tEnd - tStart)
# Out:
# It cost 34.482457 sec

# %%
result
# Out:
#                           EQIPnumber  \
# 0       [86, 69, 90, 80, 84, 50, 48]
# 1       [86, 69, 90, 80, 84, 50, 48]
# 2       [86, 69, 90, 80, 84, 50, 48]
# 3       [86, 69, 90, 80, 84, 50, 48]
# 4       [86, 69, 90, 80, 84, 50, 48]
# 5       [86, 69, 90, 80, 84, 50, 48]
# 6       [86, 69, 90, 80, 84, 50, 48]
# 7       [86, 69, 90, 80, 84, 50, 48]
# 8       [86, 69, 90, 80, 84, 50, 48]
# 9       [86, 69, 90, 80, 84, 50, 48]
# 10      [86, 69, 90, 80, 84, 50, 48]
# 11      [86, 69, 90, 80, 84, 50, 48]
# 12      [86, 69, 90, 80, 84, 50, 48]
# 13      [86, 69, 90, 80, 84, 50, 48]
# 14      [86, 69, 90, 80, 84, 50, 48]
# 15      [86, 69, 90, 80, 84, 50, 48]
# 16      [86, 69, 90, 80, 84, 50, 48]
# 17      [86, 69, 90, 80, 84, 50, 48]
# 18      [86, 69, 90, 80, 84, 50, 48]
# 19      [86, 69, 90, 80, 84, 50, 48]
# 20      [86, 69, 90, 80, 84, 50, 48]
# 21      [86, 69, 90, 80, 84, 50, 48]
# 22      [86, 69, 90, 80, 84, 50, 48]
# 23      [86, 69, 90, 80, 84, 50, 48]
# ...

# %%
"""
# 速度較慢淘汰

import time
tStart = time.time()

db_connection = sql.connect(host='localhost', database='for1121', user='root', password='apple')

df_all = pd.DataFrame()
for ele in zc_tablename:
    df_by_table = pd.read_sql('SELECT * FROM {r}'.format(r=ele), con=db_connection)
    df_all = df_all.append(df_by_table, ignore_index=True)
#     print df_by_table
tEnd = time.time()
print "It cost %f sec" % (tEnd - tStart)"""
# Out:
# It cost 59.747094 sec

# %%
#把bytesarray 變成utf-8
def decode_to_utf8(df):
    df.EQIPnumber=df.EQIPnumber.str.decode("utf-8")
    df.location=df.location.str.decode("utf-8")
    df.direct=df.direct.str.decode("utf-8")
    df.YMD=df.YMD.str.decode("utf-8")
    df.hour=df.hour.str.decode("utf-8")
    return df

df_all=decode_to_utf8(result)

# %%
"""#小測試資料集
# u'V42E2E0'
head_copy=df_all[df_all.EQIPnumber==u'V42E2E0'].head(168).reset_index(drop=True).copy()
head_copy.ix[:,'jb_result'] = None
# head_copy
#測試寫判斷位置在什麼路
jb.load_userdict("road_dict.txt")
for locatnum in range(len(head_copy.ix[:,'location'])):
    jb_cut = jb.cut(head_copy.ix[locatnum,'location'])
    temp= []
    for i in jb_cut:
        print i
        if (('路'in i) or ('街' in i) or ('大道' in i)):
            print i
            temp.append(i)
    head_copy.set_value(locatnum,'jb_result',temp)
"""
# Out:
# '#\xe5\xb0\x8f\xe6\xb8\xac\xe8\xa9\xa6\xe8\xb3\x87\xe6\x96\x99\xe9\x9b\x86\n# u\'V42E2E0\'\nhead_copy=df_all[df_all.EQIPnumber==u\'V42E2E0\'].head(168).reset_index(drop=True).copy()\nhead_copy.ix[:,\'jb_result\'] = None\n# head_copy\n#\xe6\xb8\xac\xe8\xa9\xa6\xe5\xaf\xab\xe5\x88\xa4\xe6\x96\xb7\xe4\xbd\x8d\xe7\xbd\xae\xe5\x9c\xa8\xe4\xbb\x80\xe9\xba\xbc\xe8\xb7\xaf\njb.load_userdict("road_dict.txt")\nfor locatnum in range(len(head_copy.ix[:,\'location\'])):\n    jb_cut = jb.cut(head_copy.ix[locatnum,\'location\'])\n    temp= []\n    for i in jb_cut:\n        print i\n        if ((\'\xe8\xb7\xaf\'in i) or (\'\xe8\xa1\x97\' in i) or (\'\xe5\xa4\xa7\xe9\x81\x93\' in i)):\n            print i\n            temp.append(i)\n    head_copy.set_value(locatnum,\'jb_result\',temp)\n'

# %%
def define_road(df):
    import time
    tStart = time.time()
    
    df.ix[:,'jb_result'] = None
    jb.load_userdict("road_dict.txt")
    for locatnum in range(len(df.ix[:,'location'])):
        jb_cut = jb.cut(df.ix[locatnum,'location'])
        temp= []
        for i in jb_cut:
            if (('路'in i) or ('街' in i) or ('大道' in i)):
                temp.append(i)
        temp=";".join(temp)
        df.set_value(locatnum,'jb_result',temp)
        
    tEnd = time.time()
    print "It cost %f sec" % (tEnd - tStart)

# %%
define_road(df_all)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/4s/ly8cdp1d3750yx32m1zyd3wm0000gn/T/jieba.cache
# Loading model cost 2.492 seconds.
# Prefix dict has been built succesfully.
# It cost 129.017625 sec

# %%
df_all=df_all.drop(['scooterflow','truckflow','addTotal'],axis=1)

# %%
vdlist = df_all.ix[:,'EQIPnumber'].unique().tolist()
# vdlist

# %%
df_all.columns
# Out:
# Index([ u'EQIPnumber',    u'location',      u'direct',         u'YMD',
#               u'hour',  u'laneNumber',     u'15Total',     u'carflow',
#           u'avgspeed',  u'avgPercent', u'avgCarSpace',   u'jb_result'],
#       dtype='object')

# %%
for i in df_all.jb_result.unique().tolist():
    print i
# Out:
# 汀州路
# 金門街
# 和平西路一段
# 和平西路二段
# 西藏路
# 莒光路
# 信義路一段
# 仁愛路二段
# 濟南路一段
# 忠孝東路二段
# 八德路一段
# 濟南路二段
# 忠孝東路一段
# 市民大道三段
# 忠孝西路一段
# 市民大道二段;長安東路一段
# 市民大道一段;中山北路
# 忠孝西路二段
# 鄭州路
# 街
#
# 水源路
# 路水博館
# 重慶南路三段;路
# 中華路二段
# 重慶南路三段
# 羅斯福路二段
# 和平西路;和平西路;莒光路
# 重慶南路二段
# 中山南路
# 重慶南路一段
# 杭州南路一段
# 金山南路一段
# 林森南路
# 林森北路
# 青年路
# 詔安街
# 師大路
# 汀州路三段
# 羅斯福路四段
# 林森南路;仁愛路一段
# 林森南路;路口
# 市民大道
# 八德路
# 信義路二段;路燈桿
# 信義路二段
# 羅斯福路
# 基隆路三段;汀州路三段;路
# 愛國東路

# %%
df_all.to_csv('ZC.csv',index=False)

# %%
zc_w_road=pd.read_csv('ZC.csv',encoding='utf-8')

# %%
zc_w_road.jb_result
# Out:
# 0         [u'\u6c40\u5dde\u8def']
# 1         [u'\u6c40\u5dde\u8def']
# 2         [u'\u6c40\u5dde\u8def']
# 3         [u'\u6c40\u5dde\u8def']
# 4         [u'\u6c40\u5dde\u8def']
# 5         [u'\u6c40\u5dde\u8def']
# 6         [u'\u6c40\u5dde\u8def']
# 7         [u'\u6c40\u5dde\u8def']
# 8         [u'\u6c40\u5dde\u8def']
# 9         [u'\u6c40\u5dde\u8def']
# 10        [u'\u6c40\u5dde\u8def']
# 11        [u'\u6c40\u5dde\u8def']
# 12        [u'\u6c40\u5dde\u8def']
# 13        [u'\u6c40\u5dde\u8def']
# 14        [u'\u6c40\u5dde\u8def']
# 15        [u'\u6c40\u5dde\u8def']
# 16        [u'\u6c40\u5dde\u8def']
# 17        [u'\u6c40\u5dde\u8def']
# 18        [u'\u6c40\u5dde\u8def']
# 19        [u'\u6c40\u5dde\u8def']
# 20        [u'\u6c40\u5dde\u8def']
# 21        [u'\u6c40\u5dde\u8def']
# 22        [u'\u6c40\u5dde\u8def']
# 23        [u'\u6c40\u5dde\u8def']
# 24        [u'\u6c40\u5dde\u8def']
# 25        [u'\u6c40\u5dde\u8def']
# 26        [u'\u6c40\u5dde\u8def']
# ...
